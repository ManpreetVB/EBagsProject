-- %% [markdown]
-- # [EBags]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EBags]    Script Date: 3/17/2024 11:12:00 PM ******/
CREATE DATABASE [EBags]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EBags', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EBags.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EBags_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EBags_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [EBags] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EBags].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EBags] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EBags] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EBags] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EBags] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EBags] SET ARITHABORT OFF 
GO
ALTER DATABASE [EBags] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [EBags] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EBags] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EBags] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EBags] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EBags] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EBags] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EBags] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EBags] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EBags] SET  ENABLE_BROKER 
GO
ALTER DATABASE [EBags] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EBags] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EBags] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EBags] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EBags] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EBags] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EBags] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EBags] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [EBags] SET  MULTI_USER 
GO
ALTER DATABASE [EBags] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EBags] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EBags] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EBags] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EBags] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EBags] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [EBags] SET QUERY_STORE = ON
GO
ALTER DATABASE [EBags] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Bag]

-- %%
USE [EBags]
GO

-- %%
/****** Object:  Table [dbo].[Bag]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bag](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[BagBrand] [varchar](100) NULL,
	[Material] [varchar](100) NULL,
	[BagColor] [varchar](100) NULL,
	[Price] [int] NULL,
	[BagType] [varchar](100) NULL,
	[Discount] [decimal](10, 2) NULL,
	[ImageUrl] [varchar](100) NULL,
	[Quantity] [int] NULL,
	[IsActive] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Bags]

-- %%
/****** Object:  Table [dbo].[Bags]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bags](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[BagBrand] [varchar](100) NULL,
	[Material] [varchar](100) NULL,
	[BagColor] [varchar](100) NULL,
	[Price] [varchar](100) NULL,
	[BagType] [varchar](100) NULL,
	[Discount] [decimal](10, 2) NULL,
	[Quantity] [int] NULL,
	[IsActive] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cart]

-- %%
/****** Object:  Table [dbo].[Cart]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cart](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [int] NULL,
	[BagBrand] [varchar](100) NULL,
	[BagType] [varchar](100) NULL,
	[Discount] [decimal](10, 2) NULL,
	[Quantity] [int] NULL,
	[BagID] [int] NULL,
	[TotalPrice] [decimal](10, 2) NULL,
	[Price] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderItem]

-- %%
/****** Object:  Table [dbo].[OrderItem]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderItem](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[OrderID] [int] NULL,
	[BagBrand] [varchar](100) NULL,
	[Price] [int] NULL,
	[Discount] [decimal](10, 2) NULL,
	[Quantity] [int] NULL,
	[TotalPrice] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [int] NULL,
	[OrderNumber] [int] NULL,
	[OrderTotal] [int] NULL,
	[OrderStatus] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserID] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [varchar](100) NULL,
	[LastName] [varchar](100) NULL,
	[Email] [varchar](100) NULL,
	[Password] [varchar](100) NULL,
	[Address] [varchar](1000) NULL,
	[Type] [varchar](100) NULL,
	[IsActive] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Bag]

-- %%
SET IDENTITY_INSERT [dbo].[Bag] ON 
INSERT [dbo].[Bag] ([ID], [BagBrand], [Material], [BagColor], [Price], [BagType], [Discount], [ImageUrl], [Quantity], [IsActive]) VALUES (1, N'Guess', N'Leather', N'Brown', 150, N'CrossBody Purse', CAST(10.00 AS Decimal(10, 2)), N'', 1, 1)
INSERT [dbo].[Bag] ([ID], [BagBrand], [Material], [BagColor], [Price], [BagType], [Discount], [ImageUrl], [Quantity], [IsActive]) VALUES (2, N'Michel Kores', N'Leather', N'Black', 350, N'Messenger Bag', CAST(10.00 AS Decimal(10, 2)), N'', 1, 1)
INSERT [dbo].[Bag] ([ID], [BagBrand], [Material], [BagColor], [Price], [BagType], [Discount], [ImageUrl], [Quantity], [IsActive]) VALUES (3, N'Tommy', N'Leather', N'White', 300, N'Belt Bag', CAST(10.00 AS Decimal(10, 2)), N'', 1, 1)
SET IDENTITY_INSERT [dbo].[Bag] OFF
GO

-- %% [markdown]
-- # [dbo].[Cart]

-- %%
SET IDENTITY_INSERT [dbo].[Cart] ON 
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (1, 1, N'Michel Kores', N'Messenger Bag', CAST(10.00 AS Decimal(10, 2)), 2, NULL, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (2, 3, N'Guess', N'CrossBody Purse', CAST(10.00 AS Decimal(10, 2)), 3, NULL, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (3, 2, N'Tommy', N'Belt Bag', CAST(10.00 AS Decimal(10, 2)), 4, NULL, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (4, NULL, NULL, NULL, NULL, 0, 0, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (5, 1, NULL, NULL, NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (6, 1, NULL, NULL, NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (7, 1, NULL, NULL, NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (9, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (10, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (11, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (12, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (13, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (14, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (15, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (16, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
INSERT [dbo].[Cart] ([ID], [UserID], [BagBrand], [BagType], [Discount], [Quantity], [BagID], [TotalPrice], [Price]) VALUES (17, 1, N'Guess', N'CrossBody Purse', NULL, 3, 1, NULL, NULL)
SET IDENTITY_INSERT [dbo].[Cart] OFF
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
SET IDENTITY_INSERT [dbo].[Users] ON 
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (1, N'Ben', N'Duckett', N'duckett12@gmail.com', N'cricket', N'8 Coach Way Rolleston', N'User', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (2, N'Ollie', N'Pope', N'popeollie@gmail.com', N'england', N'16 Lomu Way Rolleston', N'User', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (3, N'Joe', N'Root', N'joerootcricket@gmail.com', N'player', N'20 George Street Rolleston', N'User', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (4, N'zik', N'amiri', N'amirizk@gmail.com', N'king', N'88 sawyers arm Papanui', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (5, N'Jack', N'JB', N'jbhifi@gmail.com', N'laptop', N'27 westfield Riccarton', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (6, N'Singh', N'Brar', N'singhbrar@gmail.com', N'brarsingh', N'67 manakura street,Russley', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (7, N'', N'', N'', N'', N'', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (8, N'Dhruve', N'Jurel', N'dhcricket@gmail.com', N'19 fraquhars road Redwood,Christchurch', N'player', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (9, N'admin', N'admin', N'admin', N'42 steadman street, hornby', N'admin', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (10, N'admin', N'admin', N'admin@gmail.com', N'admin', N'47 papanui street ,christchurch', N'Users', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (11, N'Steave', N'Read', N'readindustrilian@gmaol.com', N'noel', N'67 ragiora christchurch', N'User', 1)
INSERT [dbo].[Users] ([UserID], [FirstName], [LastName], [Email], [Password], [Address], [Type], [IsActive]) VALUES (12, N'admin123', N'admin123', N'admin123@gmail.com', N'admin', N'27 george street rollestone', N'Admin', 1)
SET IDENTITY_INSERT [dbo].[Users] OFF
GO

-- %% [markdown]
-- # [dbo].[sp_AddToCart]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_AddToCart]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_AddToCart](@ID INT=null,@BagID INT,@BagBrand VARCHAR(100),@BagType VARCHAR(100),@Email VARCHAR(100)=null,
@Price DECIMAL(10,2),@Discount DECIMAL(10,2),@Quantity INT=null,@TotalPrice DECIMAL(10,2),@Output_Message VARCHAR(100) OUTPUT)
AS
 BEGIN
 DECLARE @UserID INT;  
 DECLARE @Price_ DECIMAL(10,2) 
  DECLARE @Discount_ DECIMAL(10,2);  
  DECLARE @TotalPrice_ DECIMAL(10,2) 
  

 SET @UserID = (SELECT 1 FROM Users WHERE Email = @Email);  
  SET @Price_ = (SELECT   1  FROM Bag WHERE ID = @ID);  
  SET @Discount_ = (SELECT (Price * @Quantity * Discount)/ 100 FROM Bag WHERE ID = @ID);  
  SET @TotalPrice_ = (SELECT (Price * @Quantity) - @Discount_ FROM Bag WHERE ID = @ID); 
  
   IF NOT EXISTS(SELECT 1 FROM Cart WHERE UserID = @UserID AND BagID = @ID) 
     BEGIN 
      INSERT INTO Cart(UserID,BagBrand,BagType,BagID,Price,Discount,Quantity,TotalPrice)
	  VALUES(@UserID,@BagBrand,@BagType,@BagID,@Price_,@Discount_,@Quantity,@TotalPrice_);

	  SET @Output_Message ='Item has been added to cart';
     END

   ELSE
        BEGIN
		UPDATE Cart SET Quantity = (Quantity + @Quantity) WHERE UserID = @UserID AND BagID = @ID;  
	   	 SET @Output_Message ='Item could not be added';
		 END
   END
   
   
GO

-- %% [markdown]
-- # [dbo].[sp_AddUpdateBag]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_AddUpdateBag]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_AddUpdateBag](@ID INT=null ,@BagBrand VARCHAR(100)=null,@Material VARCHAR(100)=null,@BagColor VARCHAR(100)=null,@Price INT=null,
@BagType VARCHAR(100)=null,@Discount DECIMAL(10,2)=null, @ImageUrl VARCHAR(100)=null,@Quantity INT=null,@IsActive INT=null,@ActionType VARCHAR(100)=null ,@Output_Message VARCHAR(100) OUTPUT )
AS 
BEGIN
 IF @ActionType ='ADD'
 BEGIN 
  INSERT INTO Bag(BagBrand,Material,BagColor,Price,BagType,Discount,ImageUrl,Quantity,IsActive)
  VALUES(@BagBrand,@Material,@BagColor,@Price,@BagType,@Discount,@ImageUrl,@Quantity,1);

  SET @Output_Message='Bag inserted successfully'
	
	 END
  ELSE
      BEGIN
	     SET @Output_Message='Bag not inserted'
	  END


IF @ActionType = 'UPDATE'
	BEGIN
		UPDATE Bag SET BagBrand=@BagBrand,Material=@Material,BagColor=@BagColor,Price=@Price,BagType=@BagType,Discount=@Discount,Quantity=@Quantity		
		WHERE ID = @ID;
		SET @Output_Message='Bag updated successfully'
	END
	ELSE
	BEGIN
	     SET @Output_Message='Bag not updated'
	  END

IF @ActionType = 'Delete'
	BEGIN
		UPDATE Bag SET IsActive = 0 WHERE ID = @ID;
		SET @Output_Message='Item deleted successfully'
	END

	ELSE
	BEGIN
	     SET @Output_Message='Item could not deleted'
	  END


IF @ActionType = 'Get'
	BEGIN
		SELECT * FROM Bag WHERE IsActive= 1;
		SET @Output_Message='Bag details fetched'
	END
     
	 ELSE
	BEGIN
	     SET @Output_Message='Bag details are not found'
	  END


IF @ActionType = 'GetByID'
	BEGIN
		SELECT * FROM Bag WHERE ID = @ID;
		SET @Output_Message='Item exists'
	END
	 ELSE
	BEGIN
	     SET @Output_Message='Item does not exist '
	  END

END
GO

-- %% [markdown]
-- # [dbo].[sp_CartList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_CartList]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_CartList](@Email VARCHAR(100))
AS
BEGIN
    IF @Email != 'Admin'
	BEGIN
		SELECT C.ID, B.BagBrand, B.BagType, B.Price, B.Discount, C.Quantity, C.TotalPrice FROM Cart C 
		INNER JOIN Bag B ON B.ID = C.ID
		INNER JOIN Users U ON U.UserID = C.UserID
		WHERE U.Email =  @Email;
	END
	ELSE
	BEGIN
		SELECT B.ID, B.BagBrand, B.BagType, B.Price, B.Discount, B.Quantity,  0 AS TotalPrice FROM Bag B;
	END
END;
GO

-- %% [markdown]
-- # [dbo].[sp_Login]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Login]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_Login](@Email VARCHAR(100), @Password VARCHAR(100)) 
AS
BEGIN
	
	SELECT * FROM Users WHERE Email = @Email AND Password = @Password AND IsActive=1;
	
		
END

GO

-- %% [markdown]
-- # [dbo].[sp_OrderList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_OrderList]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_OrderList](@UserID INT,
@Email VARCHAR(100) , @Type VARCHAR(100),@Output_Message VARCHAR(100) OUTPUT)
AS
BEGIN

 IF @Type = 'Admin'  
 BEGIN 
 DECLARE @ID INT =Null;
  SELECT O.ID,OrderNumber,OrderTotal,OrderStatus  
  
  ,CONCAT(U.FirstName,' ',U.LastName ) AS CustomerName 
  FROM Orders O INNER JOIN Users U  
  ON U.UserID = O.UserID;  
    SET @Output_Message='Order details fetched'
	END
     ELSE
      BEGIN
	     SET @Output_Message='Order details are not found'
	  END

	  IF @Type = 'User'  
 BEGIN  
  SELECT O.ID,OrderNumber,OrderTotal,OrderStatus  
  , CONCAT( U.FirstName,' ',U.LastName )  AS CustomerName 
  FROM Orders O INNER JOIN Users U  
  ON U.UserID = O.UserID  
  WHERE U.Email = @Email;
  SET @Output_Message='Order details fetched'
	END
     ELSE
      BEGIN
	     SET @Output_Message='Order details are not found'
	  END
  IF @Type = 'UserItems'  
 BEGIN  
  SELECT   
  O.ID, O.OrderNumber,O.OrderTotal,O.OrderStatus, B.BagBrand AS BagBrand, B.Material,B.BagColor,B.BagType,B.Price,OI.Quantity,OI.TotalPrice   
   ,CONCAT(U.FirstName,' ',U.LastName) AS CustomerName  
  , B.ImageUrl  
  FROM Orders O   
  INNER JOIN Users U ON U.UserID = O.UserID  
  INNER JOIN OrderItem OI ON OI.OrderID = O.ID  
  INNER JOIN Bag B ON B.ID = OI.ID  
  WHERE O.ID = @ID;  
    SET @Output_Message='Item details fetched'
	END
     ELSE
      BEGIN
	     SET @Output_Message='Item details are not found'
	  END   

END

GO

-- %% [markdown]
-- # [dbo].[sp_PlaceOrder]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_PlaceOrder]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 CREATE PROC [dbo].[sp_PlaceOrder](@Email  VARCHAR(100))
   AS
   BEGIN
       DECLARE @OrderNumber VARCHAR(100);
	DECLARE @OrderID INT;
	DECLARE @OrderTotal INT;
	DECLARE @UserID INT;
	SET @OrderNumber =	(SELECT NEWID());
	SET @UserID = (SELECT UserID FROM Users WHERE Email = @Email);

	IF OBJECT_ID('tempdb..#TempOrder') IS NOT NULL DROP TABLE #TempOrder; 
	
	SELECT * INTO #TempOrder 
	FROM Cart WHERE UserId = @UserID;

	SET @OrderTotal = (SELECT SUM(TotalPrice) from #TempOrder);

	INSERT INTO Orders(UserID,OrderNumber,OrderTotal,OrderStatus)
	VALUES(@UserID,@OrderNumber,@OrderTotal,'Pending');

	SET @OrderID = (SELECT ID FROM Orders WHERE OrderNumber = @OrderNumber);

	INSERT INTO OrderItem(OrderID,BagBrand,Price,Discount,Quantity,TotalPrice)
	SELECT @OrderID, BagBrand,Price,Discount,Quantity,TotalPrice FROM #TempOrder;

	DELETE FROM Cart WHERE UserId = @UserID;
END
GO

-- %% [markdown]
-- # [dbo].[sp_Registration]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Registration]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_Registration](@UserID INT,@FirstName VARCHAR(100),@LastName VARCHAR(100),@Email VARCHAR(100),@Password VARCHAR(100)
,@Address VARCHAR(1000),@Type VARCHAR(100),@IsActive INT,@Output_Message VARCHAR(100) OUTPUT)
As
BEGIN
	IF NOT EXISTS (SELECT 1 FROM Users WHERE  Email=@Email AND IsActive=1)
	BEGIN
		INSERT INTO Users(FirstName,LastName,Email,Password,Address,Type,IsActive)
		VALUES(@FirstName,@LastName,@Email,@Password,@Address,@Type,1);
		SET @Output_Message = 'User registered successfully';
	END
	ELSE
	BEGIN
		SET @Output_Message = 'User registration failed';
	END
	END
GO

-- %% [markdown]
-- # [dbo].[sp_RemoveToCart]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_RemoveToCart]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_RemoveToCart](@ID INT, @Email VARCHAR(100),@Output_Message VARCHAR(100) OUTPUT)    
AS    
BEGIN    
  DECLARE @UserID INT;    
   IF EXISTS (SELECT 1 FROM Users WHERE Email = @Email)
     BEGIN
      DELETE FROM Cart WHERE UserId = @UserId AND ID = @ID;
      SET @Output_Message ='Item has been removed from cart';
     END

    ELSE
     BEGIN
      SET @Output_Message ='Item could not be removed';
     END
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateOrderStatus]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateOrderStatus]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_UpdateOrderStatus](@OrderNumber VARCHAR(100) = NULL, @OrderStatus VARCHAR(100) = NULL,@Output_Message VARCHAR(100) OUTPUT)
AS
BEGIN
  IF EXISTS(SELECT  1 FROM Orders WHERE OrderStatus=@OrderStatus )
  BEGIN
	UPDATE Orders SET OrderStatus = @OrderStatus WHERE OrderNumber = @OrderNumber;
	SET @Output_Message='Order status updated successfully'
	  END 
	  ELSE
	  BEGIN
	  SET @Output_Message='Order status could not be updated'
	  END
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateUserProfile]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateUserProfile]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_UpdateUserProfile](@UserID INT,@FirstName VARCHAR(100),@LastName VARCHAR(100),@Email VARCHAR(100),@Password VARCHAR(100)
,@Address VARCHAR(1000),@Type VARCHAR(100),@IsActive INT,@Output_Message VARCHAR(100) OUTPUT)
AS
 BEGIN
  IF  EXISTS (SELECT 1 FROM Users WHERE UserID=@UserID AND IsActive=1)
   BEGIN
   UPDATE Users SET FirstName=@FirstName,LastName=@LastName,Email=@Email,Password=@Password,Address=@Address,Type=@Type
   WHERE UserID=@UserID AND IsActive=1;
    SET @Output_Message='User profile updated successfully';
	        END

	   ELSE
	       BEGIN
           SET @Output_Message='Please try again later';
	      END
	
END
GO

-- %% [markdown]
-- # [dbo].[sp_UserList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UserList]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_UserList](@Output_Message VARCHAR(100) OUTPUT)
As
BEGIN
 IF  EXISTS (SELECT 1 FROM Users WHERE IsActive=1)
	 BEGIN
	   SELECT*FROM Users WHERE IsActive=1;
	   SET @Output_Message='Data Available'
	 END

	 ELSE
	 BEGIN
	   SET @Output_Message='Data not Available'
	 END

END
GO

-- %% [markdown]
-- # [dbo].[sp_ViewUser]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ViewUser]    Script Date: 3/17/2024 11:12:00 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ViewUser](@UserID INT=NULL,@Email VARCHAR(100)=NULL,@Output_Message VARCHAR(100) OUTPUT)
AS 
BEGIN
	IF @UserID IS NOT null AND @UserID != 0
	BEGIN
		SELECT * FROM Users WHERE UserID = @UserID AND IsActive= 1;
		SET @Output_Message='User exists'
	END
	 ELSE
      BEGIN
	     SET @Output_Message='User does not exist'
	  END

	IF @Email IS NOT null AND @Email != ''
	BEGIN
		SELECT * FROM Users WHERE Email = @Email AND IsActive = 1;
	SET @Output_Message='User exists'
	END
	 ELSE
      BEGIN
	     SET @Output_Message='User does not exist'
	  END
END
GO

-- %% [markdown]
-- # [EBags]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [EBags] SET  READ_WRITE 
GO
